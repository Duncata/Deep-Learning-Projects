# %% [markdown]
# # <h1><center>CONVOLUTIONAL NEURAL NETWORK TRAFFIC SIGN IMAGES MULTI-CLASS CLASSIFIER</center></h1>

# %% [markdown]
# ![image.png](attachment:9b76d5a5-5386-4c51-ae00-3e740a2424a5.png)

# %% [markdown]
# #### Table of contents<a name="TABLE"></a>
# 1. [OVERVIEW](#OVERVIEW)
# 2. [GET DATA AND ANALYSE](#DATA)
# 3. [VISUALIZE DATA](#VISUALIZE)
# 4. [IMPORT SAGEMAKER/BOTO3, CREATE A SESSION, DEFINE S3 AND ROLE](#SAGEMAKER)
# 5. [UPLOAD DATA TO S3](#UPLOAD)
# 6. [TRAIN CNN LENET MODEL USING SAGEMAKER](#TRAIN)
# 7. [DEPLOY AND TEST MODEL](#DEPLOY)
# 8. [CONCLUSION](#CONCLU)

# %% [markdown]
# # 1. OVERVIEW<a name="OVERVIEW"></a>

# %% [markdown]
# Traffic sign classification is an important task for self driving cars. In this project, we run our project in AWS Sagemaker Studio using the Deep  Nerwork known  as LeNet. Our goal is to build a multiclassifier model based on deep learning to classify various traffic signs. Dataset that we are using to train the model is the German Traffic Sign Recognition Benchmark.
#
# Data Source - https://www.kaggle.com/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign

# %% [markdown]
#  **Dataset consists of 43 classes listed below:**
# - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)') ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)') ( 4, b'Speed limit (70km/h)')
# - ( 5, b'Speed limit (80km/h)') ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)') ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
# - (10, b'No passing for vehicles over 3.5 metric tons') (11, b'Right-of-way at the next intersection') (12, b'Priority road') (13, b'Yield') (14, b'Stop')
# - (15, b'No vehicles') (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
# - (18, b'General caution') (19, b'Dangerous curve to the left')
# - (20, b'Dangerous curve to the right') (21, b'Double curve')
# - (22, b'Bumpy road') (23, b'Slippery road')
# - (24, b'Road narrows on the right') (25, b'Road work')
# - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
# - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
# - (31, b'Wild animals crossing')
# - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
# - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
# - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
# - (40, b'Roundabout mandatory') (41, b'End of no passing')
# - (42, b'End of no passing by vehicles over 3.5 metric tons')

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 2. GET DATA AND ANALYSE<a name="DATA"></a>

# %%
import pickle#function that perform serialization and de-serialization

with open("train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
#there are 34,799 images sized 32 width x32 height pixel, and 3 colored w/ red, green and blue channels
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
#there are 12630 images sized 32width x32 height pixel, and 3 colored w/ red, green and blue channels
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
#there are 4410 images sized 32width x32 height pixel, and 3 colored w/ red, green and blue channels
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
y_train
# Out:
# array([41, 41, 41, ..., 25, 25, 25], dtype=uint8)

# %% [markdown]
# # 3. VISUALIZE DATA<a name="VISUALIZE"></a>

# %%
#Pick random traffic image from test set and visualize
import numpy as np
import matplotlib.pyplot as plt
i = np.random.randint(1, len(X_test))
plt.imshow(X_test[i])
print('label = ', y_test[i])
# Out:
# label =  35

# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt

# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n = len(X_test) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables
    index = np.random.randint(0, n)
    axes[i].imshow(X_test[index])
    axes[i].set_title(y_test[index], fontsize = 15)
    axes[i].axis('off') 
    
for i in np.arange(0, W_grid*L_grid):
    index = np.random.randint(0, n)
    axes[i].imshow(X_test[index])
    axes[i].set_title(y_test[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace = 0.4)

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 4. IMPORT SAGEMAKER/BOTO3, CREATE A SESSION, DEFINE S3 AND ROLE<a name="SAGEMAKER"></a>

# %%
# Boto3 is the Amazon Web Services (AWS) Software Development Kit (SDK) for Python
# Boto3 allows Python developer to write software that makes use of services like Amazon S3 and Amazon EC2

import sagemaker
import boto3

# Let's create a Sagemaker session
sagemaker_session = sagemaker.Session()

# Let's define the S3 bucket and prefix that we want to use in this session
bucket = 'sagemaker-practical-cnn' # bucket named 'sagemaker-practical' was created beforehand
prefix = 'traffic-sign-classifier' # prefix is the subfolder within the bucket.

# Let's get the execution role for the notebook instance. 
# This is the IAM role that created when creating notebook instance. We pass the role to the training job.
# AWS Identity and Access Management (IAM) role that Amazon SageMaker can assume to perform tasks on behalf (for example, reading training results, called model artifacts, from the S3 bucket and writing training results to Amazon S3). 
role = sagemaker.get_execution_role()
print(role)
# Out:
# arn:aws:iam::431550815005:role/service-role/AmazonSageMaker-ExecutionRole-20200415T140875

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 5. UPLOAD DATA TO S3<a name="UPLOAD"></a>

# %%
# Create directory to store the training and validation data

import os
os.makedirs("./data", exist_ok = True)

# %%
# Save several arrays into a single file in uncompressed .npz format
np.savez('./data/training', image = X_train, label = y_train)#save data to './data/training'
np.savez('./data/validation', image = X_test, label = y_test)

# %%
# Upload the training and validation data to S3 bucket

training_input_path   = sagemaker_session.upload_data('data/training.npz', key_prefix = prefix + '/training')
validation_input_path = sagemaker_session.upload_data('data/validation.npz', key_prefix = prefix + '/validation')

print(training_input_path)
print(validation_input_path)
# Out:
# s3://sagemaker-us-east-1-431550815005/traffic-sign-classifier/training/training.npz
# s3://sagemaker-us-east-1-431550815005/traffic-sign-classifier/validation/validation.npz

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 6. TRAIN CNN LENET MODEL USING SAGEMAKER<a name="TRAIN"></a>

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#
#
#     - Input = 32x32x3
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#     * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#
#
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#
#
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#
#
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#
#
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#
#
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
#cnn.py = Define our network and everything we need regarding the model architecture and the actual training as well of the network within that Python file.
# !pygmentize train-cnn.py
# Out:
# import argparse, os
# import numpy as np
# import tensorflow
# from tensorflow.keras import backend as K
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.utils import multi_gpu_model
#
#
# # The training code will be contained in a main gaurd (if __name__ == '__main__') so SageMaker will execute the code found in the main.
# # argparse:
# if __name__ == '__main__':
#
#     # Parser to get the arguments
#     parser = argparse.ArgumentParser()
#
#     # Model hyperparameters are being sent as command-line arguments.
#     parser.add_argument('--epochs', type=int, default=1)
#     parser.add_argument('--learning-rate', type=float, default=0.001)
#     parser.add_argument('--batch-size', type=int, default=32)
#
#
#
# ...

# %%
from sagemaker.tensorflow import TensorFlow

# To Train a TensorFlow model, we will use TensorFlow estimator from the Sagemaker SDK

# entry_point: a script that will run in a container. This script will include model description and training. 
# role: a role that's obtained The role assigned to the running notebook. 
# train_instance_count: number of container instances used to train the model.
# train_instance_type: instance type!
# framwork_version: version of Tensorflow
# py_version: Python version.
# script_mode: allows for running script in the container. 
# hyperparameters: indicate the hyperparameters for the training job such as epochs and learning rate


tf_estimator = TensorFlow(entry_point='train-cnn.py', 
                          role=role,
                          instance_count=1, 
                          instance_type='ml.c4.2xlarge',
                            use_spot_instances = True, 
                            max_run = 300,
                            max_wait = 600,
                          framework_version='1.12', 
                          py_version='py3',
                          script_mode=True,
                          hyperparameters={
                              'epochs': 15 ,
                              'batch-size': 32,
                              'learning-rate': 0.001}
                         )

# %%
tf_estimator.fit({'training': training_input_path, 'validation': validation_input_path})
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-scriptmode-2023-04-09-06-02-05-874
# 2023-04-09 06:02:08 Starting - Starting the training job...
# 2023-04-09 06:02:33 Starting - Preparing the instances for training......
# 2023-04-09 06:03:43 Downloading - Downloading input data
# 2023-04-09 06:03:43 Training - Training image download completed. Training in progress...2023-04-09 06:03:53,632 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2023-04-09 06:03:53,638 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-09 06:03:53,834 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-09 06:03:53,849 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# ...

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 7. DEPLOY AND TEST MODEL <a name="DEPLOY"></a>

# %%
# Deploying the model

import time

tf_endpoint_name = 'trafficsignclassifier-' + time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

tf_predictor = tf_estimator.deploy(initial_instance_count = 1,
                         instance_type = 'ml.t2.medium',  
                         endpoint_name = tf_endpoint_name)
# Out:
# WARNING:sagemaker.deprecations:update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.tensorflow.model:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating model with name: sagemaker-tensorflow-scriptmode-2023-04-09-06-07-36-355
# INFO:sagemaker:Creating endpoint-config with name trafficsignclassifier-2023-04-09-06-07-36
# INFO:sagemaker:Creating endpoint with name trafficsignclassifier-2023-04-09-06-07-36
# -----!

# %%
# Making predictions from the end point

# %matplotlib inline
import random
import matplotlib.pyplot as plt

#Pre-processing the images

num_samples = 5
indices = random.sample(range(X_test.shape[0] - 1), num_samples)
images = X_test[indices]/255
labels = y_test[indices]

for i in range(num_samples):
    plt.subplot(1,num_samples,i+1)
    plt.imshow(images[i])
    plt.title(labels[i])
    plt.axis('off')

# Making predictions 

prediction = tf_predictor.predict(images.reshape(num_samples, 32, 32, 3))['predictions']
prediction = np.array(prediction)
predicted_label = prediction.argmax(axis=1)
print('Predicted labels are: {}'.format(predicted_label))
# Out:
# Predicted labels are: [16 17 32 17  4]

# %%
# Deleting the end-point
tf_predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting endpoint configuration with name: trafficsignclassifier-2023-04-09-06-07-36
# INFO:sagemaker:Deleting endpoint with name: trafficsignclassifier-2023-04-09-06-07-36

# %% [markdown]
# #### [Back to Top](#TABLE)

# %% [markdown]
# # 8. CONCLUSION<a name="CONCLU"></a>

# %% [markdown]
# After 15 epoch, Our model where able to learn from the teaffic image data and have a good accuracy of 99.1% and a validation loss of 90%. The accuracy loss(0.0308) and validation(0.6809)) loss are both going down, a good sign that it does not memorize the data or no overfitting happening. After experimenting in changing the filter and adding more convolutional layer, the accuracy is the same at 99% and validation accuracy(91%) increase by 1%. But the accuracy loss(0.0325) and validation loss(0.5749) went down, the lower the loss the better the model. We did not apply drop out, in Convolutional layers it exploit pixels within a spatial neighbourhood to extract the right features to feed into Dense layers. Dropout would destroy this relationship and thus prevent your model from successfully learning these features.
#
# We deploy our trained model classifier in an endpoint and start to make inferences based on it. We feed 5 traffic sign image at the endpoint using the test data and predicted all the 5 image correctly as shown in the picture above:
# - (16, b'Vehicles over 3.5 metric tons prohibited')
# - (17, b'No entry')
# - (32, b'End of all speed and passing limits')
# - (18, b'General caution')
# - ( 4, b'Speed limit (70km/h)')
